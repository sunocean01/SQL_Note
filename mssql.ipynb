# %%
import pandas as pd
import pymysql as psql
import pyodbc

# %% [raw]
# https://blog.csdn.net/MHapdream/article/details/9076527/

# %%
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %%
# conn = psql.connect(host="CN-SHA-P-MSQS01",
#                     database="SEN4XDB",
#                     user="SENSIRION-ZH\osun",
                    
#                    )

# %%
import sys

# %%
sys.executable
# Out:
# 'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0\\Scripts\\python.exe'

# %%
sys.path
# Out:
# ['C:\\python\\function\\SQL',
#  'C:\\Users\\osun\\Desktop\\Python\\Function\\testfile',
#  'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0\\Scripts\\python38.zip',
#  'C:\\Program Files\\WinPython38_64bit\\python-3.8.6.amd64\\DLLs',
#  'C:\\Program Files\\WinPython38_64bit\\python-3.8.6.amd64\\lib',
#  'C:\\Program Files\\WinPython38_64bit\\python-3.8.6.amd64',
#  'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0',
#  '',
#  'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0\\lib\\site-packages',
#  'c:\\users\\osun\\gitlab\\python-pm-calib-golden-samples',
#  'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0\\lib\\site-packages\\pylatus',
#  'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0\\lib\\site-packages\\win32',
#  'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0\\lib\\site-packages\\win32\\lib',
#  'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0\\lib\\site-packages\\Pythonwin',
#  'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0\\lib\\site-packages\\IPython\\extensions',
# ...

# %%
server = 'CN-SHA-D-MSQL01'
database = 'SEN5XDB'

# %%
conn = pyodbc.connect("DRIVER={{SQL Server}};SERVER={Server};DATABASE={DB};Trusted_Connection=yes, autocommit=True".format(Server=server, DB=database))

# %%
# cur = conn.cursor()

# %%
# cur.execute("show tables")

# %%
# query="select top 10 * from MC03.t_MeasureData"

# query="select name from sysobjects where xtype='U'"   #获取当前数据库中所有表名

query="select name from syscolumns where id=object_id('MS01.t_Limits')"   #获取表中的所有字段

# %%
tabs = pd.read_sql(query,con=conn)
# Out:
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
tabs
# Out:
#                                  name
# 0                  t_SubstrateSession
# 1          t_SubstrateSession_LogFile
# 2                 t_MeasureDataCommon
# 3         t_SubstrateSession_Facility
# 4                           t_Contact
# 5                t_ApplicationSession
# 6    t_SubstrateSession_Configuration
# 7                              t_Site
# 8          t_SubstrateSession_LogFile
# 9                  t_SubstrateSession
# 10                       t_MS02Module
# 11        t_SubstrateSession_Facility
# 12                          t_Contact
# 13              t_EnvironmentSetPoint
# 14   t_SubstrateSession_Configuration
# 15                             t_Site
# 16                           t_Limits
# 17                       t_MC04Module
# 18         t_SubstrateSession_LogFile
# 19                     t_LimitsCommon
# 20              t_MeasureData_Archive
# 21        t_SubstrateSession_Facility
# 22                          t_Contact
# 23              t_EnvironmentSetPoint
# ...

# %%
tabs['lg'] = tabs['name'].map(lambda x: len(x))

# %%
# tabs

# %%
for tab in tabs['name'].tolist():
    print(tab)
    query="select name from syscolumns where id=object_id('MC03.{}')".format(tab)
    dt = pd.read_sql(query,con=conn)
    dt = dt.T
    dt.to_csv("tab_{}_columns.csv".format(tab))
    print("*"*50)
# Out:
# t_Limits
# **************************************************
# t_LimitsCommon
# **************************************************
# t_ApplicationSession
# **************************************************
# t_MeasureData_Archive
# **************************************************
# t_MeasureDataCommon_Archive
# **************************************************
# t_SubstrateSession
# **************************************************
# t_MeasureDataCommon
# **************************************************
# t_MeasureData
# **************************************************
# t_ApplicationSession
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# ...

# %%
pd.read_sql(query,con=conn).sort_values("name")
# Out:
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                    name
# 0              LimitsId
# 1                   MD5
# 2           T004002_LTL
# 3           T004002_UTL
# 4           T007001_LTL
# 5           T007001_UTL
# 6           T027001_LTL
# 7           T027001_UTL
# 8           T031001_LTL
# 9           T031001_UTL
# 10          T031002_LTL
# 11          T031002_UTL
# 12          T031003_LTL
# 13          T031003_UTL
# 14          T031004_LTL
# 15          T031004_UTL
# 16          T031005_LTL
# 17          T031005_UTL
# 18          T031006_LTL
# 19          T031006_UTL
# 20          T031010_LTL
# 21          T031010_UTL
# 22          T031011_LTL
# 23          T031011_UTL
# 24          T032001_LTL
# ...

# %%
hex(117)
# Out:
# '0x75'
