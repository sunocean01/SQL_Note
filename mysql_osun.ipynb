# %%
import pandas as pd
import pymysql as psql
import pyodbc

# %% [raw]
# https://blog.csdn.net/MHapdream/article/details/9076527/

# %%
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %%
# conn = psql.connect(host="CN-SHA-P-MSQS01",
#                     database="SEN4XDB",
#                     user="SENSIRION-ZH\osun",
                    
#                    )
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# C:\Program Files\WinPython38_64bit\python-3.8.6.amd64\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# C:\Program Files\WinPython38_64bit\python-3.8.6.amd64\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-3ae0fdc7e158> in <module>
# ----> 1 conn = psql.connect(host="CN-SHA-P-MSQS01",
#       2                     database="SEN4XDB",
#       3                     user="SENSIRION-ZH\osun",
#       4
#       5                    )
#
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (2003, "Can't connect to MySQL server on 'CN-SHA-P-MSQS01' (timed out)")

# %%
import sys

# %%
sys.executable
# Out:
# 'C:\\work\\virtenvs\\3p8_64bit_SensiPython_4p0\\Scripts\\python.exe'

# %%
server = 'CN-SHA-P-MSQS01'
database = 'SEN4XDB'

# %%
conn = pyodbc.connect("DRIVER={{SQL Server}};SERVER={Server};DATABASE={DB};Trusted_Connection=yes, autocommit=True".format(Server=server, DB=database))

# %%
# cur = conn.cursor()

# %%
# cur.execute("show tables")

# %%
# query="select top 10 * from MC03.t_MeasureData"
query="select name from sysobjects where xtype='U'"   #获取当前数据库中所有表名
# query="select name from syscolumns where id=object_id('MC03.t_MeasureData')"   #获取表中的所有字段

# %%
tabs = pd.read_sql(query,con=conn)
# Out:
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
pd.read_sql(query,con=conn)
# Out:
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                                  name
# 0                            t_Limits
# 1                      t_LimitsCommon
# 2                t_ApplicationSession
# 3               t_MeasureData_Archive
# 4         t_MeasureDataCommon_Archive
# 5                  t_SubstrateSession
# 6                 t_MeasureDataCommon
# 7                       t_MeasureData
# 8                t_ApplicationSession
# 9         t_MeasureDataCommon_Archive
# 10   t_SubstrateSession_Configuration
# 11                 t_SubstrateSession
# 12         t_SubstrateSession_LogFile
# 13                t_MeasureDataCommon
# 14        t_SubstrateSession_Facility
# 15                          t_Contact
# 16               t_ApplicationSession
# 17   t_SubstrateSession_Configuration
# 18                             t_Site
# 19         t_SubstrateSession_LogFile
# 20                 t_SubstrateSession
# 21                       t_MS02Module
# 22        t_SubstrateSession_Facility
# 23                          t_Contact
# 24              t_EnvironmentSetPoint
# 25   t_SubstrateSession_Configuration
# 26                             t_Site
# 27                           t_Limits
# 28                       t_MC04Module
# 29         t_SubstrateSession_LogFile
# 30                     t_LimitsCommon
# 31              t_MeasureData_Archive
# 32        t_SubstrateSession_Facility
# 33                          t_Contact
# 34              t_EnvironmentSetPoint
# 35                      t_MeasureData
# 36                           t_Limits
# 37                             t_Site
# 38                     t_LimitsCommon
# 39                       t_MC02Module
# 40              t_MeasureData_Archive
# 41               t_SensiDBInformation
# 42               t_VersionInformation
# 43        t_MeasureDataCommon_Archive
# 44                    t_ChangeHistory
# 45              t_EnvironmentSetPoint
# 46                           t_Module
# 47                      t_MeasureData
# 48                t_MeasureDataCommon
# 49                           t_Limits
# 50                             t_Tray
# 51                     t_LimitsCommon
# 52                    t_Configuration
# 53              t_MeasureData_Archive
# 54                          t_LogFile
# 55               t_ApplicationSession
# 56        t_MeasureDataCommon_Archive
# 57                         t_Facility
# 58                 t_SubstrateSession
# 59                      t_FileVersion
# 60                t_MeasureDataCommon
# 61                      t_MeasureData
# 62                     t_FacilityType
# 63                    t_ProcessRecipe
# 64               t_ApplicationSession
# 65        t_MeasureDataCommon_Archive
# 66      t_ProcessRecipe_Configuration
# 67   t_SubstrateSession_Configuration
# 68                 t_SubstrateSession
# 69              t_ProcessRecipe_Admin
# 70         t_SubstrateSession_LogFile
# 71                t_MeasureDataCommon
# 72                      t_Application
# 73        t_SubstrateSession_Facility
# 74                       t_BinQuality
# 75               t_ApplicationSession
# 76                         t_Material
# 77                          t_Contact
# 78   t_SubstrateSession_Configuration
# 79                     t_ProductGroup
# 80                             t_Site
# 81                 t_SubstrateSession
# 82                     t_ResultStatus
# 83         t_SubstrateSession_LogFile
# 84                       t_MQ01Module
# 85                   t_SubstrateGrade
# 86        t_SubstrateSession_Facility
# 87                         t_TestSpec
# 88                          t_Contact
# 89               t_ApplicationSession
# 90              t_EnvironmentSetPoint
# 91   t_SubstrateSession_Configuration
# 92                             t_Site
# 93                           t_Limits
# 94                       t_MS01Module
# 95         t_SubstrateSession_LogFile
# 96                 t_SubstrateSession
# 97                     t_LimitsCommon
# 98              t_MeasureData_Archive
# 99        t_SubstrateSession_Facility
# 100                         t_Contact
# 101             t_EnvironmentSetPoint
# 102  t_SubstrateSession_Configuration
# 103                     t_MeasureData
# 104                          t_Limits
# 105                            t_Site
# 106                    t_LimitsCommon
# 107                      t_MC03Module
# 108        t_SubstrateSession_LogFile
# 109             t_MeasureData_Archive
# 110       t_SubstrateSession_Facility
# 111       t_MeasureDataCommon_Archive
# 112                         t_Contact
# 113             t_EnvironmentSetPoint
# 114                     t_MeasureData
# 115               t_MeasureDataCommon
# 116                          t_Limits
# 117                            t_Site
# 118                    t_LimitsCommon
# 119                      t_MC01Module
# 120             t_MeasureData_Archive
# 121       t_MeasureDataCommon_Archive
# 122             t_EnvironmentSetPoint
# 123               t_MeasureDataCommon
# 124                     t_MeasureData

# %%
for tab in tabs['name']:
    print(tab)
    query="select name from syscolumns where id=object_id('MC03.{}')".format(tab)
    print(pd.read_sql(query,con=conn))
    print("*"*50)
# Out:
# t_Limits
#                           name
# 0                     LimitsId
# 1                          MD5
# 2                  T001001_LTL
# 3                  T001001_UTL
# 4                  T001002_LTL
# 5                  T001002_UTL
# 6                  T001003_LTL
# 7                  T001003_UTL
# 8                  T004002_LTL
# 9                  T004002_UTL
# 10                 T008001_LTL
# 11                 T008001_UTL
# 12                 T008002_LTL
# 13                 T008002_UTL
# 14                 T008003_LTL
# 15                 T008003_UTL
# 16                 T008004_LTL
# 17                 T008004_UTL
# 18                 T008005_LTL
# 19                 T008005_UTL
# 20                 T008006_LTL
# 21                 T008006_UTL
# 22                 T008007_LTL
# 23                 T008007_UTL
# 24                 T008008_LTL
# 25                 T008008_UTL
# 26                 T008009_LTL
# 27                 T008009_UTL
# 28                 T008010_LTL
# 29                 T008010_UTL
# 30                 T008011_LTL
# 31                 T008011_UTL
# 32                 T008012_LTL
# 33                 T008012_UTL
# 34                 T008013_LTL
# 35                 T008013_UTL
# 36                 T008014_LTL
# 37                 T008014_UTL
# 38                 T008015_LTL
# 39                 T008015_UTL
# 40                 T008016_LTL
# 41                 T008016_UTL
# 42                 T008017_LTL
# 43                 T008017_UTL
# 44                 T008018_LTL
# 45                 T008018_UTL
# 46                 T008019_LTL
# 47                 T008019_UTL
# 48                 T008020_LTL
# 49                 T008020_UTL
# 50                 T008021_LTL
# 51                 T008021_UTL
# 52                 T008022_LTL
# 53                 T008022_UTL
# 54                 T008023_LTL
# 55                 T008023_UTL
# 56                 T008024_LTL
# 57                 T008024_UTL
# 58                 T008025_LTL
# 59                 T008025_UTL
# 60                 T008026_LTL
# 61                 T008026_UTL
# 62                 T008027_LTL
# 63                 T008027_UTL
# 64                 T008028_LTL
# 65                 T008028_UTL
# 66                 T008029_LTL
# 67                 T008029_UTL
# 68                 T008030_LTL
# 69                 T008030_UTL
# 70                 T008031_LTL
# 71                 T008031_UTL
# 72                 T008032_LTL
# 73                 T008032_UTL
# 74                 T008033_LTL
# 75                 T008033_UTL
# 76                 T008034_LTL
# 77                 T008034_UTL
# 78                 T008035_LTL
# 79                 T008035_UTL
# 80                 T008036_LTL
# 81                 T008036_UTL
# 82                 T008037_LTL
# 83                 T008037_UTL
# 84                 T008038_LTL
# 85                 T008038_UTL
# 86                 T008039_LTL
# 87                 T008039_UTL
# 88                 T008040_LTL
# 89                 T008040_UTL
# 90                 T008041_LTL
# 91                 T008041_UTL
# 92                 T008042_LTL
# 93                 T008042_UTL
# 94                 T008043_LTL
# 95                 T008043_UTL
# 96                 T008044_LTL
# 97                 T008044_UTL
# 98                 T008045_LTL
# 99                 T008045_UTL
# 100                T008046_LTL
# 101                T008046_UTL
# 102                T008047_LTL
# 103                T008047_UTL
# 104                T008048_LTL
# 105                T008048_UTL
# 106                T008049_LTL
# 107                T008049_UTL
# 108                T008050_LTL
# 109                T008050_UTL
# 110                T008051_LTL
# 111                T008051_UTL
# 112                T008052_LTL
# 113                T008052_UTL
# 114                T008053_LTL
# 115                T008053_UTL
# 116                T008054_LTL
# 117                T008054_UTL
# 118                T008055_LTL
# 119                T008055_UTL
# 120                T008056_LTL
# 121                T008056_UTL
# 122                T008057_LTL
# 123                T008057_UTL
# 124                T008058_LTL
# 125                T008058_UTL
# 126                T008059_LTL
# 127                T008059_UTL
# 128                T008060_LTL
# 129                T008060_UTL
# 130                T008061_LTL
# 131                T008061_UTL
# 132                T008062_LTL
# 133                T008062_UTL
# 134                T008063_LTL
# 135                T008063_UTL
# 136                T008064_LTL
# 137                T008064_UTL
# 138                T008065_LTL
# 139                T008065_UTL
# 140                T008066_LTL
# 141                T008066_UTL
# 142                T008067_LTL
# 143                T008067_UTL
# 144                T008068_LTL
# 145                T008068_UTL
# 146                T008069_LTL
# 147                T008069_UTL
# 148                T008070_LTL
# 149                T008070_UTL
# 150                T008071_LTL
# 151                T008071_UTL
# 152                T008072_LTL
# 153                T008072_UTL
# 154                T008073_LTL
# 155                T008073_UTL
# 156                T009001_LTL
# 157                T009001_UTL
# 158                T010002_LTL
# 159                T010002_UTL
# 160                T010003_LTL
# 161                T010003_UTL
# 162                T031001_LTL
# 163                T031001_UTL
# 164                T031002_LTL
# 165                T031002_UTL
# 166                T031003_LTL
# 167                T031003_UTL
# 168                T031004_LTL
# 169                T031004_UTL
# 170                T031005_LTL
# 171                T031005_UTL
# 172                T031006_LTL
# 173                T031006_UTL
# 174                T050001_LTL
# 175                T050001_UTL
# 176                T050002_LTL
# 177                T050002_UTL
# 178                T050003_LTL
# 179                T050003_UTL
# 180                T055001_LTL
# 181                T055001_UTL
# 182                T056001_LTL
# 183                T056001_UTL
# 184                T060001_LTL
# 185                T060001_UTL
# 186                T060002_LTL
# 187                T060002_UTL
# 188                T060003_LTL
# 189                T060003_UTL
# 190                T060004_LTL
# 191                T060004_UTL
# 192                T060005_LTL
# 193                T060005_UTL
# 194                T060006_LTL
# 195                T060006_UTL
# 196                T060007_LTL
# 197                T060007_UTL
# 198                T060008_LTL
# 199                T060008_UTL
# 200                T060009_LTL
# 201                T060009_UTL
# 202  T085001_Remeasurement_LTL
# 203  T085001_Remeasurement_UTL
# 204  T085002_Remeasurement_LTL
# 205  T085002_Remeasurement_UTL
# 206  T085003_Remeasurement_LTL
# 207  T085003_Remeasurement_UTL
# 208  T085004_Remeasurement_LTL
# 209  T085004_Remeasurement_UTL
# 210  T085005_Remeasurement_LTL
# 211  T085005_Remeasurement_UTL
# 212  T085006_Remeasurement_LTL
# 213  T085006_Remeasurement_UTL
# 214            T086001_Arz_LTL
# 215            T086001_Arz_UTL
# 216            T086001_Kcl_LTL
# 217            T086001_Kcl_UTL
# 218            T086002_Arz_LTL
# 219            T086002_Arz_UTL
# 220            T086002_Kcl_LTL
# 221            T086002_Kcl_UTL
# 222            T086003_Arz_LTL
# 223            T086003_Arz_UTL
# 224            T086003_Kcl_LTL
# 225            T086003_Kcl_UTL
# 226            T086004_Arz_LTL
# 227            T086004_Arz_UTL
# 228            T086004_Kcl_LTL
# 229            T086004_Kcl_UTL
# 230            T086005_Arz_LTL
# 231            T086005_Arz_UTL
# 232            T086005_Kcl_LTL
# 233            T086005_Kcl_UTL
# 234            T086006_Arz_LTL
# 235            T086006_Arz_UTL
# 236            T086006_Kcl_LTL
# 237            T086006_Kcl_UTL
# 238            T086007_Arz_LTL
# 239            T086007_Arz_UTL
# 240            T086007_Kcl_LTL
# 241            T086007_Kcl_UTL
# 242    T099001_Calibration_LTL
# 243    T099001_Calibration_UTL
# 244          T099001_Final_LTL
# 245          T099001_Final_UTL
# 246    T099002_Calibration_LTL
# 247    T099002_Calibration_UTL
# 248          T099002_Final_LTL
# 249          T099002_Final_UTL
# 250    T099004_Calibration_LTL
# 251    T099004_Calibration_UTL
# 252          T099004_Final_LTL
# 253          T099004_Final_UTL
# 254    T099005_Calibration_LTL
# 255    T099005_Calibration_UTL
# 256          T099005_Final_LTL
# 257          T099005_Final_UTL
# 258    T099007_Calibration_LTL
# 259    T099007_Calibration_UTL
# 260          T099007_Final_LTL
# 261          T099007_Final_UTL
# 262    T099008_Calibration_LTL
# 263    T099008_Calibration_UTL
# 264          T099008_Final_LTL
# 265          T099008_Final_UTL
# 266                    T15_LTL
# 267                    T15_UTL
# 268          T601001_Final_LTL
# 269          T601001_Final_UTL
# 270          T601001_Reset_LTL
# 271          T601001_Reset_UTL
# **************************************************
# t_LimitsCommon
#                           name
# 0               LimitsCommonId
# 1                          MD5
# 2                  T000001_LTL
# 3                  T000001_UTL
# 4              T006001_Arz_LTL
# 5              T006001_Arz_UTL
# 6              T006001_Kcl_LTL
# 7              T006001_Kcl_UTL
# 8    T006001_Remeasurement_LTL
# 9    T006001_Remeasurement_UTL
# 10             T006002_Arz_LTL
# 11             T006002_Arz_UTL
# 12             T006002_Kcl_LTL
# 13             T006002_Kcl_UTL
# 14   T006002_Remeasurement_LTL
# 15   T006002_Remeasurement_UTL
# 16             T006005_Arz_LTL
# 17             T006005_Arz_UTL
# 18             T006005_Kcl_LTL
# 19             T006005_Kcl_UTL
# 20   T006005_Remeasurement_LTL
# 21   T006005_Remeasurement_UTL
# 22             T006006_Arz_LTL
# 23             T006006_Arz_UTL
# 24             T006006_Kcl_LTL
# 25             T006006_Kcl_UTL
# 26   T006006_Remeasurement_LTL
# 27   T006006_Remeasurement_UTL
# 28             T006007_Arz_LTL
# 29             T006007_Arz_UTL
# 30             T006007_Kcl_LTL
# 31             T006007_Kcl_UTL
# 32   T006007_Remeasurement_LTL
# 33   T006007_Remeasurement_UTL
# 34             T006008_Arz_LTL
# 35             T006008_Arz_UTL
# 36             T006008_Kcl_LTL
# 37             T006008_Kcl_UTL
# 38   T006008_Remeasurement_LTL
# 39   T006008_Remeasurement_UTL
# 40             T006009_Arz_LTL
# 41             T006009_Arz_UTL
# 42             T006009_Kcl_LTL
# 43             T006009_Kcl_UTL
# 44   T006009_Remeasurement_LTL
# 45   T006009_Remeasurement_UTL
# 46             T006010_Arz_LTL
# 47             T006010_Arz_UTL
# 48             T006010_Kcl_LTL
# 49             T006010_Kcl_UTL
# 50   T006010_Remeasurement_LTL
# 51   T006010_Remeasurement_UTL
# 52             T006011_Arz_LTL
# 53             T006011_Arz_UTL
# 54             T006011_Kcl_LTL
# 55             T006011_Kcl_UTL
# 56   T006011_Remeasurement_LTL
# 57   T006011_Remeasurement_UTL
# 58             T006012_Arz_LTL
# 59             T006012_Arz_UTL
# 60             T006012_Kcl_LTL
# 61             T006012_Kcl_UTL
# 62   T006012_Remeasurement_LTL
# 63   T006012_Remeasurement_UTL
# 64             T006013_Arz_LTL
# 65             T006013_Arz_UTL
# 66             T006013_Kcl_LTL
# 67             T006013_Kcl_UTL
# 68   T006013_Remeasurement_LTL
# 69   T006013_Remeasurement_UTL
# 70             T006014_Arz_LTL
# 71             T006014_Arz_UTL
# 72             T006014_Kcl_LTL
# 73             T006014_Kcl_UTL
# 74   T006014_Remeasurement_LTL
# 75   T006014_Remeasurement_UTL
# 76             T006015_Arz_LTL
# 77             T006015_Arz_UTL
# 78             T006015_Kcl_LTL
# 79             T006015_Kcl_UTL
# 80   T006015_Remeasurement_LTL
# 81   T006015_Remeasurement_UTL
# 82             T006016_Arz_LTL
# 83             T006016_Arz_UTL
# 84             T006016_Kcl_LTL
# 85             T006016_Kcl_UTL
# 86   T006016_Remeasurement_LTL
# 87   T006016_Remeasurement_UTL
# 88             T006017_Arz_LTL
# 89             T006017_Arz_UTL
# 90             T006017_Kcl_LTL
# 91             T006017_Kcl_UTL
# 92   T006017_Remeasurement_LTL
# 93   T006017_Remeasurement_UTL
# 94             T006018_Arz_LTL
# 95             T006018_Arz_UTL
# 96             T006018_Kcl_LTL
# 97             T006018_Kcl_UTL
# 98   T006018_Remeasurement_LTL
# 99   T006018_Remeasurement_UTL
# 100            T006019_Arz_LTL
# 101            T006019_Arz_UTL
# 102            T006019_Kcl_LTL
# 103            T006019_Kcl_UTL
# 104  T006019_Remeasurement_LTL
# 105  T006019_Remeasurement_UTL
# 106            T006020_Arz_LTL
# 107            T006020_Arz_UTL
# 108            T006020_Kcl_LTL
# 109            T006020_Kcl_UTL
# 110  T006020_Remeasurement_LTL
# 111  T006020_Remeasurement_UTL
# 112            T006021_Arz_LTL
# 113            T006021_Arz_UTL
# 114            T006021_Kcl_LTL
# 115            T006021_Kcl_UTL
# 116  T006021_Remeasurement_LTL
# 117  T006021_Remeasurement_UTL
# 118            T006022_Arz_LTL
# 119            T006022_Arz_UTL
# 120            T006022_Kcl_LTL
# 121            T006022_Kcl_UTL
# 122  T006022_Remeasurement_LTL
# 123  T006022_Remeasurement_UTL
# 124            T006023_Arz_LTL
# 125            T006023_Arz_UTL
# 126            T006023_Kcl_LTL
# 127            T006023_Kcl_UTL
# 128  T006023_Remeasurement_LTL
# 129  T006023_Remeasurement_UTL
# 130            T006024_Arz_LTL
# 131            T006024_Arz_UTL
# 132            T006024_Kcl_LTL
# 133            T006024_Kcl_UTL
# 134  T006024_Remeasurement_LTL
# 135  T006024_Remeasurement_UTL
# 136            T006036_Arz_LTL
# 137            T006036_Arz_UTL
# 138            T006036_Kcl_LTL
# 139            T006036_Kcl_UTL
# 140  T006036_Remeasurement_LTL
# 141  T006036_Remeasurement_UTL
# 142            T006038_Arz_LTL
# 143            T006038_Arz_UTL
# 144            T006038_Kcl_LTL
# 145            T006038_Kcl_UTL
# 146  T006038_Remeasurement_LTL
# 147  T006038_Remeasurement_UTL
# 148            T006042_Arz_LTL
# 149            T006042_Arz_UTL
# 150            T006042_Kcl_LTL
# 151            T006042_Kcl_UTL
# 152  T006042_Remeasurement_LTL
# 153  T006042_Remeasurement_UTL
# 154            T006043_Arz_LTL
# 155            T006043_Arz_UTL
# 156            T006043_Kcl_LTL
# 157            T006043_Kcl_UTL
# 158  T006043_Remeasurement_LTL
# 159  T006043_Remeasurement_UTL
# 160            T006044_Arz_LTL
# 161            T006044_Arz_UTL
# 162            T006044_Kcl_LTL
# 163            T006044_Kcl_UTL
# 164  T006044_Remeasurement_LTL
# 165  T006044_Remeasurement_UTL
# 166                T020001_LTL
# 167                T020001_UTL
# 168                T020002_LTL
# 169                T020002_UTL
# 170                T020003_LTL
# 171                T020003_UTL
# 172                T020004_LTL
# 173                T020004_UTL
# 174                T020005_LTL
# 175                T020005_UTL
# 176                T020006_LTL
# 177                T020006_UTL
# 178                T020007_LTL
# 179                T020007_UTL
# 180                T020008_LTL
# 181                T020008_UTL
# 182                T020009_LTL
# 183                T020009_UTL
# 184                T020010_LTL
# 185                T020010_UTL
# 186                T150011_LTL
# 187                T150011_UTL
# **************************************************
# t_ApplicationSession
#                    name
# 0         ApplicationId
# 1  ApplicationSessionId
# 2           EndDateTime
# 3        EndDateTimeUTC
# 4         ExecutionMode
# 5        FileIdentifier
# 6           MachineName
# 7       SetupFacilityId
# 8         StartDateTime
# 9      StartDateTimeUTC
# **************************************************
# t_MeasureData_Archive
#                              name
# 0                       AllWithin
# 1                ContactElapsedMs
# 2                       ContactId
# 3           EnvironmentSetPointId
# 4          EnvironmentSetPointPos
# 5      IsSubstrateGradeProduction
# 6                        LimitsId
# 7                   MeasureDataId
# 8                          SiteId
# 9                         T001001
# 10                 T001001_Result
# 11                        T001002
# 12                 T001002_Result
# 13                        T001003
# 14                 T001003_Result
# 15                        T004001
# 16                 T004001_Result
# 17                        T004002
# 18                 T004002_Result
# 19                        T008001
# 20                 T008001_Result
# 21                        T008002
# 22                 T008002_Result
# 23                        T008003
# 24                 T008003_Result
# 25                        T008004
# 26                 T008004_Result
# 27                        T008005
# 28                 T008005_Result
# 29                        T008006
# 30                 T008006_Result
# 31                        T008007
# 32                 T008007_Result
# 33                        T008008
# 34                 T008008_Result
# 35                        T008009
# 36                 T008009_Result
# 37                        T008010
# 38                 T008010_Result
# 39                        T008011
# 40                 T008011_Result
# 41                        T008012
# 42                 T008012_Result
# 43                        T008013
# 44                 T008013_Result
# 45                        T008014
# 46                 T008014_Result
# 47                        T008015
# 48                 T008015_Result
# 49                        T008016
# 50                 T008016_Result
# 51                        T008017
# 52                 T008017_Result
# 53                        T008018
# 54                 T008018_Result
# 55                        T008019
# 56                 T008019_Result
# 57                        T008020
# 58                 T008020_Result
# 59                        T008021
# 60                 T008021_Result
# 61                        T008022
# 62                 T008022_Result
# 63                        T008023
# 64                 T008023_Result
# 65                        T008024
# 66                 T008024_Result
# 67                        T008025
# 68                 T008025_Result
# 69                        T008026
# 70                 T008026_Result
# 71                        T008027
# 72                 T008027_Result
# 73                        T008028
# 74                 T008028_Result
# 75                        T008029
# 76                 T008029_Result
# 77                        T008030
# 78                 T008030_Result
# 79                        T008031
# 80                 T008031_Result
# 81                        T008032
# 82                 T008032_Result
# 83                        T008033
# 84                 T008033_Result
# 85                        T008034
# 86                 T008034_Result
# 87                        T008035
# 88                 T008035_Result
# 89                        T008036
# 90                 T008036_Result
# 91                        T008037
# 92                 T008037_Result
# 93                        T008038
# 94                 T008038_Result
# 95                        T008039
# 96                 T008039_Result
# 97                        T008040
# 98                 T008040_Result
# 99                        T008041
# 100                T008041_Result
# 101                       T008042
# 102                T008042_Result
# 103                       T008043
# 104                T008043_Result
# 105                       T008044
# 106                T008044_Result
# 107                       T008045
# 108                T008045_Result
# 109                       T008046
# 110                T008046_Result
# 111                       T008047
# 112                T008047_Result
# 113                       T008048
# 114                T008048_Result
# 115                       T008049
# 116                T008049_Result
# 117                       T008050
# 118                T008050_Result
# 119                       T008051
# 120                T008051_Result
# 121                       T008052
# 122                T008052_Result
# 123                       T008053
# 124                T008053_Result
# 125                       T008054
# 126                T008054_Result
# 127                       T008055
# 128                T008055_Result
# 129                       T008056
# 130                T008056_Result
# 131                       T008057
# 132                T008057_Result
# 133                       T008058
# 134                T008058_Result
# 135                       T008059
# 136                T008059_Result
# 137                       T008060
# 138                T008060_Result
# 139                       T008061
# 140                T008061_Result
# 141                       T008062
# 142                T008062_Result
# 143                       T008063
# 144                T008063_Result
# 145                       T008064
# 146                T008064_Result
# 147                       T008065
# 148                T008065_Result
# 149                       T008066
# 150                T008066_Result
# 151                       T008067
# 152                T008067_Result
# 153                       T008068
# 154                T008068_Result
# 155                       T008069
# 156                T008069_Result
# 157                       T008070
# 158                T008070_Result
# 159                       T008071
# 160                T008071_Result
# 161                       T008072
# 162                T008072_Result
# 163                       T008073
# 164                T008073_Result
# 165                       T009001
# 166                T009001_Result
# 167                       T010001
# 168                T010001_Result
# 169                       T010002
# 170                T010002_Result
# 171                       T010003
# 172                T010003_Result
# 173                       T013001
# 174                T013001_Result
# 175                       T031001
# 176                T031001_Result
# 177                       T031002
# 178                T031002_Result
# 179                       T031003
# 180                T031003_Result
# 181                       T031004
# 182                T031004_Result
# 183                       T031005
# 184                T031005_Result
# 185                       T031006
# 186                T031006_Result
# 187                       T050001
# 188                T050001_Result
# 189                       T050002
# 190                T050002_Result
# 191                       T050003
# 192                T050003_Result
# 193                       T055001
# 194                T055001_Result
# 195                       T056001
# 196                T056001_Result
# 197                       T060001
# 198                T060001_Result
# 199                       T060002
# 200                T060002_Result
# 201                       T060003
# 202                T060003_Result
# 203                       T060004
# 204                T060004_Result
# 205                       T060005
# 206                T060005_Result
# 207                       T060006
# 208                T060006_Result
# 209                       T060007
# 210                T060007_Result
# 211                       T060008
# 212                T060008_Result
# 213                       T060009
# 214                T060009_Result
# 215         T085001_Remeasurement
# 216  T085001_Remeasurement_Result
# 217         T085002_Remeasurement
# 218  T085002_Remeasurement_Result
# 219         T085003_Remeasurement
# 220  T085003_Remeasurement_Result
# 221         T085004_Remeasurement
# 222  T085004_Remeasurement_Result
# 223         T085005_Remeasurement
# 224  T085005_Remeasurement_Result
# 225         T085006_Remeasurement
# 226  T085006_Remeasurement_Result
# 227                   T086001_Arz
# 228            T086001_Arz_Result
# 229                   T086001_Kcl
# 230            T086001_Kcl_Result
# 231                   T086002_Arz
# 232            T086002_Arz_Result
# 233                   T086002_Kcl
# 234            T086002_Kcl_Result
# 235                   T086003_Arz
# 236            T086003_Arz_Result
# 237                   T086003_Kcl
# 238            T086003_Kcl_Result
# 239                   T086004_Arz
# 240            T086004_Arz_Result
# 241                   T086004_Kcl
# 242            T086004_Kcl_Result
# 243                   T086005_Arz
# 244            T086005_Arz_Result
# 245                   T086005_Kcl
# 246            T086005_Kcl_Result
# 247                   T086006_Arz
# 248            T086006_Arz_Result
# 249                   T086006_Kcl
# 250            T086006_Kcl_Result
# 251                   T086007_Arz
# 252            T086007_Arz_Result
# 253                   T086007_Kcl
# 254            T086007_Kcl_Result
# 255           T099001_Calibration
# 256    T099001_Calibration_Result
# 257                 T099001_Final
# 258          T099001_Final_Result
# 259           T099002_Calibration
# 260    T099002_Calibration_Result
# 261                 T099002_Final
# 262          T099002_Final_Result
# 263           T099003_Calibration
# 264    T099003_Calibration_Result
# 265                 T099003_Final
# 266          T099003_Final_Result
# 267           T099004_Calibration
# 268    T099004_Calibration_Result
# 269                 T099004_Final
# 270          T099004_Final_Result
# 271           T099005_Calibration
# 272    T099005_Calibration_Result
# 273                 T099005_Final
# 274          T099005_Final_Result
# 275           T099006_Calibration
# 276    T099006_Calibration_Result
# 277                 T099006_Final
# 278          T099006_Final_Result
# 279           T099007_Calibration
# 280    T099007_Calibration_Result
# 281                 T099007_Final
# 282          T099007_Final_Result
# 283           T099008_Calibration
# 284    T099008_Calibration_Result
# 285                 T099008_Final
# 286          T099008_Final_Result
# 287                           T15
# 288                    T15_Result
# 289                 T601001_Final
# 290          T601001_Final_Result
# 291                 T601001_Reset
# 292          T601001_Reset_Result
# 293                 X_OnSubstrate
# 294                 Y_OnSubstrate
# **************************************************
# t_MeasureDataCommon_Archive
#                              name
# 0                       AllWithin
# 1                ContactElapsedMs
# 2                       ContactId
# 3           EnvironmentSetPointId
# 4          EnvironmentSetPointPos
# 5      IsSubstrateGradeProduction
# 6                  LimitsCommonId
# 7             MeasureDataCommonId
# 8                         T000001
# 9                  T000001_Result
# 10                    T006001_Arz
# 11             T006001_Arz_Result
# 12                    T006001_Kcl
# 13             T006001_Kcl_Result
# 14          T006001_Remeasurement
# 15   T006001_Remeasurement_Result
# 16                    T006002_Arz
# 17             T006002_Arz_Result
# 18                    T006002_Kcl
# 19             T006002_Kcl_Result
# 20          T006002_Remeasurement
# 21   T006002_Remeasurement_Result
# 22                    T006005_Arz
# 23             T006005_Arz_Result
# 24                    T006005_Kcl
# 25             T006005_Kcl_Result
# 26          T006005_Remeasurement
# 27   T006005_Remeasurement_Result
# 28                    T006006_Arz
# 29             T006006_Arz_Result
# 30                    T006006_Kcl
# 31             T006006_Kcl_Result
# 32          T006006_Remeasurement
# 33   T006006_Remeasurement_Result
# 34                    T006007_Arz
# 35             T006007_Arz_Result
# 36                    T006007_Kcl
# 37             T006007_Kcl_Result
# 38          T006007_Remeasurement
# 39   T006007_Remeasurement_Result
# 40                    T006008_Arz
# 41             T006008_Arz_Result
# 42                    T006008_Kcl
# 43             T006008_Kcl_Result
# 44          T006008_Remeasurement
# 45   T006008_Remeasurement_Result
# 46                    T006009_Arz
# 47             T006009_Arz_Result
# 48                    T006009_Kcl
# 49             T006009_Kcl_Result
# 50          T006009_Remeasurement
# 51   T006009_Remeasurement_Result
# 52                    T006010_Arz
# 53             T006010_Arz_Result
# 54                    T006010_Kcl
# 55             T006010_Kcl_Result
# 56          T006010_Remeasurement
# 57   T006010_Remeasurement_Result
# 58                    T006011_Arz
# 59             T006011_Arz_Result
# 60                    T006011_Kcl
# 61             T006011_Kcl_Result
# 62          T006011_Remeasurement
# 63   T006011_Remeasurement_Result
# 64                    T006012_Arz
# 65             T006012_Arz_Result
# 66                    T006012_Kcl
# 67             T006012_Kcl_Result
# 68          T006012_Remeasurement
# 69   T006012_Remeasurement_Result
# 70                    T006013_Arz
# 71             T006013_Arz_Result
# 72                    T006013_Kcl
# 73             T006013_Kcl_Result
# 74          T006013_Remeasurement
# 75   T006013_Remeasurement_Result
# 76                    T006014_Arz
# 77             T006014_Arz_Result
# 78                    T006014_Kcl
# 79             T006014_Kcl_Result
# 80          T006014_Remeasurement
# 81   T006014_Remeasurement_Result
# 82                    T006015_Arz
# 83             T006015_Arz_Result
# 84                    T006015_Kcl
# 85             T006015_Kcl_Result
# 86          T006015_Remeasurement
# 87   T006015_Remeasurement_Result
# 88                    T006016_Arz
# 89             T006016_Arz_Result
# 90                    T006016_Kcl
# 91             T006016_Kcl_Result
# 92          T006016_Remeasurement
# 93   T006016_Remeasurement_Result
# 94                    T006017_Arz
# 95             T006017_Arz_Result
# 96                    T006017_Kcl
# 97             T006017_Kcl_Result
# 98          T006017_Remeasurement
# 99   T006017_Remeasurement_Result
# 100                   T006018_Arz
# 101            T006018_Arz_Result
# 102                   T006018_Kcl
# 103            T006018_Kcl_Result
# 104         T006018_Remeasurement
# 105  T006018_Remeasurement_Result
# 106                   T006019_Arz
# 107            T006019_Arz_Result
# 108                   T006019_Kcl
# 109            T006019_Kcl_Result
# 110         T006019_Remeasurement
# 111  T006019_Remeasurement_Result
# 112                   T006020_Arz
# 113            T006020_Arz_Result
# 114                   T006020_Kcl
# 115            T006020_Kcl_Result
# 116         T006020_Remeasurement
# 117  T006020_Remeasurement_Result
# 118                   T006021_Arz
# 119            T006021_Arz_Result
# 120                   T006021_Kcl
# 121            T006021_Kcl_Result
# 122         T006021_Remeasurement
# 123  T006021_Remeasurement_Result
# 124                   T006022_Arz
# 125            T006022_Arz_Result
# 126                   T006022_Kcl
# 127            T006022_Kcl_Result
# 128         T006022_Remeasurement
# 129  T006022_Remeasurement_Result
# 130                   T006023_Arz
# 131            T006023_Arz_Result
# 132                   T006023_Kcl
# 133            T006023_Kcl_Result
# 134         T006023_Remeasurement
# 135  T006023_Remeasurement_Result
# 136                   T006024_Arz
# 137            T006024_Arz_Result
# 138                   T006024_Kcl
# 139            T006024_Kcl_Result
# 140         T006024_Remeasurement
# 141  T006024_Remeasurement_Result
# 142                   T006036_Arz
# 143            T006036_Arz_Result
# 144                   T006036_Kcl
# 145            T006036_Kcl_Result
# 146         T006036_Remeasurement
# 147  T006036_Remeasurement_Result
# 148                   T006038_Arz
# 149            T006038_Arz_Result
# 150                   T006038_Kcl
# 151            T006038_Kcl_Result
# 152         T006038_Remeasurement
# 153  T006038_Remeasurement_Result
# 154                   T006042_Arz
# 155            T006042_Arz_Result
# 156                   T006042_Kcl
# 157            T006042_Kcl_Result
# 158         T006042_Remeasurement
# 159  T006042_Remeasurement_Result
# 160                   T006043_Arz
# 161            T006043_Arz_Result
# 162                   T006043_Kcl
# 163            T006043_Kcl_Result
# 164         T006043_Remeasurement
# 165  T006043_Remeasurement_Result
# 166                   T006044_Arz
# 167            T006044_Arz_Result
# 168                   T006044_Kcl
# 169            T006044_Kcl_Result
# 170         T006044_Remeasurement
# 171  T006044_Remeasurement_Result
# 172                       T020001
# 173                T020001_Result
# 174                       T020002
# 175                T020002_Result
# 176                       T020003
# 177                T020003_Result
# 178                       T020004
# 179                T020004_Result
# 180                       T020005
# 181                T020005_Result
# 182                       T020006
# 183                T020006_Result
# 184                       T020007
# 185                T020007_Result
# 186                       T020008
# 187                T020008_Result
# 188                       T020009
# 189                T020009_Result
# 190                       T020010
# 191                T020010_Result
# 192                       T150001
# 193                T150001_Result
# 194                       T150002
# 195                T150002_Result
# 196                       T150003
# 197                T150003_Result
# 198                       T150004
# 199                T150004_Result
# 200                       T150005
# 201                T150005_Result
# 202                       T150006
# 203                T150006_Result
# 204                       T150007
# 205                T150007_Result
# 206                       T150008
# 207                T150008_Result
# 208                       T150009
# 209                T150009_Result
# 210                       T150010
# 211                T150010_Result
# 212                       T150011
# 213                T150011_Result
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# **************************************************
# t_SubstrateSession
#                         name
# 0       ApplicationSessionId
# 1          ChamberFacilityId
# 2                ChamberSlot
# 3                    Comment
# 4                EndDateTime
# 5             EndDateTimeUTC
# 6             FileIdentifier
# 7                 MaterialId
# 8                   Operator
# 9             ProductGroupId
# 10           ProductionOrder
# 11  RelativeSessionDirectory
# 12               SessionGuid
# 13            SessionOrdinal
# 14             StartDateTime
# 15          StartDateTimeUTC
# 16          SubstrateGradeId
# 17               SubstrateNr
# 18        SubstrateSessionId
# 19                TestSpecId
# 20                    TrayId
# **************************************************
# t_MeasureDataCommon
#                              name
# 0                       AllWithin
# 1                ContactElapsedMs
# 2                       ContactId
# 3           EnvironmentSetPointId
# 4          EnvironmentSetPointPos
# 5      IsSubstrateGradeProduction
# 6                  LimitsCommonId
# 7             MeasureDataCommonId
# 8                         T000001
# 9                  T000001_Result
# 10                    T006001_Arz
# 11             T006001_Arz_Result
# 12                    T006001_Kcl
# 13             T006001_Kcl_Result
# 14          T006001_Remeasurement
# 15   T006001_Remeasurement_Result
# 16                    T006002_Arz
# 17             T006002_Arz_Result
# 18                    T006002_Kcl
# 19             T006002_Kcl_Result
# 20          T006002_Remeasurement
# 21   T006002_Remeasurement_Result
# 22                    T006005_Arz
# 23             T006005_Arz_Result
# 24                    T006005_Kcl
# 25             T006005_Kcl_Result
# 26          T006005_Remeasurement
# 27   T006005_Remeasurement_Result
# 28                    T006006_Arz
# 29             T006006_Arz_Result
# 30                    T006006_Kcl
# 31             T006006_Kcl_Result
# 32          T006006_Remeasurement
# 33   T006006_Remeasurement_Result
# 34                    T006007_Arz
# 35             T006007_Arz_Result
# 36                    T006007_Kcl
# 37             T006007_Kcl_Result
# 38          T006007_Remeasurement
# 39   T006007_Remeasurement_Result
# 40                    T006008_Arz
# 41             T006008_Arz_Result
# 42                    T006008_Kcl
# 43             T006008_Kcl_Result
# 44          T006008_Remeasurement
# 45   T006008_Remeasurement_Result
# 46                    T006009_Arz
# 47             T006009_Arz_Result
# 48                    T006009_Kcl
# 49             T006009_Kcl_Result
# 50          T006009_Remeasurement
# 51   T006009_Remeasurement_Result
# 52                    T006010_Arz
# 53             T006010_Arz_Result
# 54                    T006010_Kcl
# 55             T006010_Kcl_Result
# 56          T006010_Remeasurement
# 57   T006010_Remeasurement_Result
# 58                    T006011_Arz
# 59             T006011_Arz_Result
# 60                    T006011_Kcl
# 61             T006011_Kcl_Result
# 62          T006011_Remeasurement
# 63   T006011_Remeasurement_Result
# 64                    T006012_Arz
# 65             T006012_Arz_Result
# 66                    T006012_Kcl
# 67             T006012_Kcl_Result
# 68          T006012_Remeasurement
# 69   T006012_Remeasurement_Result
# 70                    T006013_Arz
# 71             T006013_Arz_Result
# 72                    T006013_Kcl
# 73             T006013_Kcl_Result
# 74          T006013_Remeasurement
# 75   T006013_Remeasurement_Result
# 76                    T006014_Arz
# 77             T006014_Arz_Result
# 78                    T006014_Kcl
# 79             T006014_Kcl_Result
# 80          T006014_Remeasurement
# 81   T006014_Remeasurement_Result
# 82                    T006015_Arz
# 83             T006015_Arz_Result
# 84                    T006015_Kcl
# 85             T006015_Kcl_Result
# 86          T006015_Remeasurement
# 87   T006015_Remeasurement_Result
# 88                    T006016_Arz
# 89             T006016_Arz_Result
# 90                    T006016_Kcl
# 91             T006016_Kcl_Result
# 92          T006016_Remeasurement
# 93   T006016_Remeasurement_Result
# 94                    T006017_Arz
# 95             T006017_Arz_Result
# 96                    T006017_Kcl
# 97             T006017_Kcl_Result
# 98          T006017_Remeasurement
# 99   T006017_Remeasurement_Result
# 100                   T006018_Arz
# 101            T006018_Arz_Result
# 102                   T006018_Kcl
# 103            T006018_Kcl_Result
# 104         T006018_Remeasurement
# 105  T006018_Remeasurement_Result
# 106                   T006019_Arz
# 107            T006019_Arz_Result
# 108                   T006019_Kcl
# 109            T006019_Kcl_Result
# 110         T006019_Remeasurement
# 111  T006019_Remeasurement_Result
# 112                   T006020_Arz
# 113            T006020_Arz_Result
# 114                   T006020_Kcl
# 115            T006020_Kcl_Result
# 116         T006020_Remeasurement
# 117  T006020_Remeasurement_Result
# 118                   T006021_Arz
# 119            T006021_Arz_Result
# 120                   T006021_Kcl
# 121            T006021_Kcl_Result
# 122         T006021_Remeasurement
# 123  T006021_Remeasurement_Result
# 124                   T006022_Arz
# 125            T006022_Arz_Result
# 126                   T006022_Kcl
# 127            T006022_Kcl_Result
# 128         T006022_Remeasurement
# 129  T006022_Remeasurement_Result
# 130                   T006023_Arz
# 131            T006023_Arz_Result
# 132                   T006023_Kcl
# 133            T006023_Kcl_Result
# 134         T006023_Remeasurement
# 135  T006023_Remeasurement_Result
# 136                   T006024_Arz
# 137            T006024_Arz_Result
# 138                   T006024_Kcl
# 139            T006024_Kcl_Result
# 140         T006024_Remeasurement
# 141  T006024_Remeasurement_Result
# 142                   T006036_Arz
# 143            T006036_Arz_Result
# 144                   T006036_Kcl
# 145            T006036_Kcl_Result
# 146         T006036_Remeasurement
# 147  T006036_Remeasurement_Result
# 148                   T006038_Arz
# 149            T006038_Arz_Result
# 150                   T006038_Kcl
# 151            T006038_Kcl_Result
# 152         T006038_Remeasurement
# 153  T006038_Remeasurement_Result
# 154                   T006042_Arz
# 155            T006042_Arz_Result
# 156                   T006042_Kcl
# 157            T006042_Kcl_Result
# 158         T006042_Remeasurement
# 159  T006042_Remeasurement_Result
# 160                   T006043_Arz
# 161            T006043_Arz_Result
# 162                   T006043_Kcl
# 163            T006043_Kcl_Result
# 164         T006043_Remeasurement
# 165  T006043_Remeasurement_Result
# 166                   T006044_Arz
# 167            T006044_Arz_Result
# 168                   T006044_Kcl
# 169            T006044_Kcl_Result
# 170         T006044_Remeasurement
# 171  T006044_Remeasurement_Result
# 172                       T020001
# 173                T020001_Result
# 174                       T020002
# 175                T020002_Result
# 176                       T020003
# 177                T020003_Result
# 178                       T020004
# 179                T020004_Result
# 180                       T020005
# 181                T020005_Result
# 182                       T020006
# 183                T020006_Result
# 184                       T020007
# 185                T020007_Result
# 186                       T020008
# 187                T020008_Result
# 188                       T020009
# 189                T020009_Result
# 190                       T020010
# 191                T020010_Result
# 192                       T150001
# 193                T150001_Result
# 194                       T150002
# 195                T150002_Result
# 196                       T150003
# 197                T150003_Result
# 198                       T150004
# 199                T150004_Result
# 200                       T150005
# 201                T150005_Result
# 202                       T150006
# 203                T150006_Result
# 204                       T150007
# 205                T150007_Result
# 206                       T150008
# 207                T150008_Result
# 208                       T150009
# 209                T150009_Result
# 210                       T150010
# 211                T150010_Result
# 212                       T150011
# 213                T150011_Result
# **************************************************
# t_MeasureData
#                              name
# 0                       AllWithin
# 1                ContactElapsedMs
# 2                       ContactId
# 3           EnvironmentSetPointId
# 4          EnvironmentSetPointPos
# 5      IsSubstrateGradeProduction
# 6                        LimitsId
# 7                   MeasureDataId
# 8                          SiteId
# 9                         T001001
# 10                 T001001_Result
# 11                        T001002
# 12                 T001002_Result
# 13                        T001003
# 14                 T001003_Result
# 15                        T004001
# 16                 T004001_Result
# 17                        T004002
# 18                 T004002_Result
# 19                        T008001
# 20                 T008001_Result
# 21                        T008002
# 22                 T008002_Result
# 23                        T008003
# 24                 T008003_Result
# 25                        T008004
# 26                 T008004_Result
# 27                        T008005
# 28                 T008005_Result
# 29                        T008006
# 30                 T008006_Result
# 31                        T008007
# 32                 T008007_Result
# 33                        T008008
# 34                 T008008_Result
# 35                        T008009
# 36                 T008009_Result
# 37                        T008010
# 38                 T008010_Result
# 39                        T008011
# 40                 T008011_Result
# 41                        T008012
# 42                 T008012_Result
# 43                        T008013
# 44                 T008013_Result
# 45                        T008014
# 46                 T008014_Result
# 47                        T008015
# 48                 T008015_Result
# 49                        T008016
# 50                 T008016_Result
# 51                        T008017
# 52                 T008017_Result
# 53                        T008018
# 54                 T008018_Result
# 55                        T008019
# 56                 T008019_Result
# 57                        T008020
# 58                 T008020_Result
# 59                        T008021
# 60                 T008021_Result
# 61                        T008022
# 62                 T008022_Result
# 63                        T008023
# 64                 T008023_Result
# 65                        T008024
# 66                 T008024_Result
# 67                        T008025
# 68                 T008025_Result
# 69                        T008026
# 70                 T008026_Result
# 71                        T008027
# 72                 T008027_Result
# 73                        T008028
# 74                 T008028_Result
# 75                        T008029
# 76                 T008029_Result
# 77                        T008030
# 78                 T008030_Result
# 79                        T008031
# 80                 T008031_Result
# 81                        T008032
# 82                 T008032_Result
# 83                        T008033
# 84                 T008033_Result
# 85                        T008034
# 86                 T008034_Result
# 87                        T008035
# 88                 T008035_Result
# 89                        T008036
# 90                 T008036_Result
# 91                        T008037
# 92                 T008037_Result
# 93                        T008038
# 94                 T008038_Result
# 95                        T008039
# 96                 T008039_Result
# 97                        T008040
# 98                 T008040_Result
# 99                        T008041
# 100                T008041_Result
# 101                       T008042
# 102                T008042_Result
# 103                       T008043
# 104                T008043_Result
# 105                       T008044
# 106                T008044_Result
# 107                       T008045
# 108                T008045_Result
# 109                       T008046
# 110                T008046_Result
# 111                       T008047
# 112                T008047_Result
# 113                       T008048
# 114                T008048_Result
# 115                       T008049
# 116                T008049_Result
# 117                       T008050
# 118                T008050_Result
# 119                       T008051
# 120                T008051_Result
# 121                       T008052
# 122                T008052_Result
# 123                       T008053
# 124                T008053_Result
# 125                       T008054
# 126                T008054_Result
# 127                       T008055
# 128                T008055_Result
# 129                       T008056
# 130                T008056_Result
# 131                       T008057
# 132                T008057_Result
# 133                       T008058
# 134                T008058_Result
# 135                       T008059
# 136                T008059_Result
# 137                       T008060
# 138                T008060_Result
# 139                       T008061
# 140                T008061_Result
# 141                       T008062
# 142                T008062_Result
# 143                       T008063
# 144                T008063_Result
# 145                       T008064
# 146                T008064_Result
# 147                       T008065
# 148                T008065_Result
# 149                       T008066
# 150                T008066_Result
# 151                       T008067
# 152                T008067_Result
# 153                       T008068
# 154                T008068_Result
# 155                       T008069
# 156                T008069_Result
# 157                       T008070
# 158                T008070_Result
# 159                       T008071
# 160                T008071_Result
# 161                       T008072
# 162                T008072_Result
# 163                       T008073
# 164                T008073_Result
# 165                       T009001
# 166                T009001_Result
# 167                       T010001
# 168                T010001_Result
# 169                       T010002
# 170                T010002_Result
# 171                       T010003
# 172                T010003_Result
# 173                       T013001
# 174                T013001_Result
# 175                       T031001
# 176                T031001_Result
# 177                       T031002
# ...
# 52                    T006010_Arz
# 53             T006010_Arz_Result
# 54                    T006010_Kcl
# 55             T006010_Kcl_Result
# 56          T006010_Remeasurement
# 57   T006010_Remeasurement_Result
# 58                    T006011_Arz
# 59             T006011_Arz_Result
# 60                    T006011_Kcl
# 61             T006011_Kcl_Result
# 62          T006011_Remeasurement
# 63   T006011_Remeasurement_Result
# 64                    T006012_Arz
# 65             T006012_Arz_Result
# 66                    T006012_Kcl
# 67             T006012_Kcl_Result
# 68          T006012_Remeasurement
# 69   T006012_Remeasurement_Result
# 70                    T006013_Arz
# 71             T006013_Arz_Result
# 72                    T006013_Kcl
# 73             T006013_Kcl_Result
# 74          T006013_Remeasurement
# 75   T006013_Remeasurement_Result
# 76                    T006014_Arz
# 77             T006014_Arz_Result
# 78                    T006014_Kcl
# 79             T006014_Kcl_Result
# 80          T006014_Remeasurement
# 81   T006014_Remeasurement_Result
# 82                    T006015_Arz
# 83             T006015_Arz_Result
# 84                    T006015_Kcl
# 85             T006015_Kcl_Result
# 86          T006015_Remeasurement
# 87   T006015_Remeasurement_Result
# 88                    T006016_Arz
# 89             T006016_Arz_Result
# 90                    T006016_Kcl
# 91             T006016_Kcl_Result
# 92          T006016_Remeasurement
# 93   T006016_Remeasurement_Result
# 94                    T006017_Arz
# 95             T006017_Arz_Result
# 96                    T006017_Kcl
# 97             T006017_Kcl_Result
# 98          T006017_Remeasurement
# 99   T006017_Remeasurement_Result
# 100                   T006018_Arz
# 101            T006018_Arz_Result
# 102                   T006018_Kcl
# 103            T006018_Kcl_Result
# 104         T006018_Remeasurement
# 105  T006018_Remeasurement_Result
# 106                   T006019_Arz
# 107            T006019_Arz_Result
# 108                   T006019_Kcl
# 109            T006019_Kcl_Result
# 110         T006019_Remeasurement
# 111  T006019_Remeasurement_Result
# 112                   T006020_Arz
# 113            T006020_Arz_Result
# 114                   T006020_Kcl
# 115            T006020_Kcl_Result
# 116         T006020_Remeasurement
# 117  T006020_Remeasurement_Result
# 118                   T006021_Arz
# 119            T006021_Arz_Result
# 120                   T006021_Kcl
# 121            T006021_Kcl_Result
# 122         T006021_Remeasurement
# 123  T006021_Remeasurement_Result
# 124                   T006022_Arz
# 125            T006022_Arz_Result
# 126                   T006022_Kcl
# 127            T006022_Kcl_Result
# 128         T006022_Remeasurement
# 129  T006022_Remeasurement_Result
# 130                   T006023_Arz
# 131            T006023_Arz_Result
# 132                   T006023_Kcl
# 133            T006023_Kcl_Result
# 134         T006023_Remeasurement
# 135  T006023_Remeasurement_Result
# 136                   T006024_Arz
# 137            T006024_Arz_Result
# 138                   T006024_Kcl
# 139            T006024_Kcl_Result
# 140         T006024_Remeasurement
# 141  T006024_Remeasurement_Result
# 142                   T006036_Arz
# 143            T006036_Arz_Result
# 144                   T006036_Kcl
# 145            T006036_Kcl_Result
# 146         T006036_Remeasurement
# 147  T006036_Remeasurement_Result
# 148                   T006038_Arz
# 149            T006038_Arz_Result
# 150                   T006038_Kcl
# 151            T006038_Kcl_Result
# 152         T006038_Remeasurement
# 153  T006038_Remeasurement_Result
# 154                   T006042_Arz
# 155            T006042_Arz_Result
# 156                   T006042_Kcl
# 157            T006042_Kcl_Result
# 158         T006042_Remeasurement
# 159  T006042_Remeasurement_Result
# 160                   T006043_Arz
# 161            T006043_Arz_Result
# 162                   T006043_Kcl
# 163            T006043_Kcl_Result
# 164         T006043_Remeasurement
# 165  T006043_Remeasurement_Result
# 166                   T006044_Arz
# 167            T006044_Arz_Result
# 168                   T006044_Kcl
# 169            T006044_Kcl_Result
# 170         T006044_Remeasurement
# 171  T006044_Remeasurement_Result
# 172                       T020001
# 173                T020001_Result
# 174                       T020002
# 175                T020002_Result
# 176                       T020003
# 177                T020003_Result
# 178                       T020004
# 179                T020004_Result
# 180                       T020005
# 181                T020005_Result
# 182                       T020006
# 183                T020006_Result
# 184                       T020007
# 185                T020007_Result
# 186                       T020008
# 187                T020008_Result
# 188                       T020009
# 189                T020009_Result
# 190                       T020010
# 191                T020010_Result
# 192                       T150001
# 193                T150001_Result
# 194                       T150002
# 195                T150002_Result
# 196                       T150003
# 197                T150003_Result
# 198                       T150004
# 199                T150004_Result
# 200                       T150005
# 201                T150005_Result
# 202                       T150006
# 203                T150006_Result
# 204                       T150007
# 205                T150007_Result
# 206                       T150008
# 207                T150008_Result
# 208                       T150009
# 209                T150009_Result
# 210                       T150010
# 211                T150010_Result
# 212                       T150011
# 213                T150011_Result
# **************************************************
# t_MeasureData
#                              name
# 0                       AllWithin
# 1                ContactElapsedMs
# 2                       ContactId
# 3           EnvironmentSetPointId
# 4          EnvironmentSetPointPos
# 5      IsSubstrateGradeProduction
# 6                        LimitsId
# 7                   MeasureDataId
# 8                          SiteId
# 9                         T001001
# 10                 T001001_Result
# 11                        T001002
# 12                 T001002_Result
# 13                        T001003
# 14                 T001003_Result
# 15                        T004001
# 16                 T004001_Result
# 17                        T004002
# 18                 T004002_Result
# 19                        T008001
# 20                 T008001_Result
# 21                        T008002
# 22                 T008002_Result
# 23                        T008003
# 24                 T008003_Result
# 25                        T008004
# 26                 T008004_Result
# 27                        T008005
# 28                 T008005_Result
# 29                        T008006
# 30                 T008006_Result
# 31                        T008007
# 32                 T008007_Result
# 33                        T008008
# 34                 T008008_Result
# 35                        T008009
# 36                 T008009_Result
# 37                        T008010
# 38                 T008010_Result
# 39                        T008011
# 40                 T008011_Result
# 41                        T008012
# 42                 T008012_Result
# 43                        T008013
# 44                 T008013_Result
# 45                        T008014
# 46                 T008014_Result
# 47                        T008015
# 48                 T008015_Result
# 49                        T008016
# 50                 T008016_Result
# 51                        T008017
# 52                 T008017_Result
# 53                        T008018
# 54                 T008018_Result
# 55                        T008019
# 56                 T008019_Result
# 57                        T008020
# 58                 T008020_Result
# 59                        T008021
# 60                 T008021_Result
# 61                        T008022
# 62                 T008022_Result
# 63                        T008023
# 64                 T008023_Result
# 65                        T008024
# 66                 T008024_Result
# 67                        T008025
# 68                 T008025_Result
# 69                        T008026
# 70                 T008026_Result
# 71                        T008027
# 72                 T008027_Result
# 73                        T008028
# 74                 T008028_Result
# 75                        T008029
# 76                 T008029_Result
# 77                        T008030
# 78                 T008030_Result
# 79                        T008031
# 80                 T008031_Result
# 81                        T008032
# 82                 T008032_Result
# 83                        T008033
# 84                 T008033_Result
# 85                        T008034
# 86                 T008034_Result
# 87                        T008035
# 88                 T008035_Result
# 89                        T008036
# 90                 T008036_Result
# 91                        T008037
# 92                 T008037_Result
# 93                        T008038
# 94                 T008038_Result
# 95                        T008039
# 96                 T008039_Result
# 97                        T008040
# 98                 T008040_Result
# 99                        T008041
# 100                T008041_Result
# 101                       T008042
# 102                T008042_Result
# 103                       T008043
# 104                T008043_Result
# 105                       T008044
# 106                T008044_Result
# 107                       T008045
# 108                T008045_Result
# 109                       T008046
# 110                T008046_Result
# 111                       T008047
# 112                T008047_Result
# 113                       T008048
# 114                T008048_Result
# 115                       T008049
# 116                T008049_Result
# 117                       T008050
# 118                T008050_Result
# 119                       T008051
# 120                T008051_Result
# 121                       T008052
# 122                T008052_Result
# 123                       T008053
# 124                T008053_Result
# 125                       T008054
# 126                T008054_Result
# 127                       T008055
# 128                T008055_Result
# 129                       T008056
# 130                T008056_Result
# 131                       T008057
# 132                T008057_Result
# 133                       T008058
# 134                T008058_Result
# 135                       T008059
# 136                T008059_Result
# 137                       T008060
# 138                T008060_Result
# 139                       T008061
# 140                T008061_Result
# 141                       T008062
# 142                T008062_Result
# 143                       T008063
# 144                T008063_Result
# 145                       T008064
# 146                T008064_Result
# 147                       T008065
# 148                T008065_Result
# 149                       T008066
# 150                T008066_Result
# 151                       T008067
# 152                T008067_Result
# 153                       T008068
# 154                T008068_Result
# 155                       T008069
# 156                T008069_Result
# 157                       T008070
# 158                T008070_Result
# 159                       T008071
# 160                T008071_Result
# 161                       T008072
# 162                T008072_Result
# 163                       T008073
# 164                T008073_Result
# 165                       T009001
# 166                T009001_Result
# 167                       T010001
# 168                T010001_Result
# 169                       T010002
# 170                T010002_Result
# 171                       T010003
# 172                T010003_Result
# 173                       T013001
# 174                T013001_Result
# 175                       T031001
# 176                T031001_Result
# 177                       T031002
# 178                T031002_Result
# 179                       T031003
# 180                T031003_Result
# 181                       T031004
# 182                T031004_Result
# 183                       T031005
# 184                T031005_Result
# 185                       T031006
# 186                T031006_Result
# 187                       T050001
# 188                T050001_Result
# 189                       T050002
# 190                T050002_Result
# 191                       T050003
# 192                T050003_Result
# 193                       T055001
# 194                T055001_Result
# 195                       T056001
# 196                T056001_Result
# 197                       T060001
# 198                T060001_Result
# 199                       T060002
# 200                T060002_Result
# 201                       T060003
# 202                T060003_Result
# 203                       T060004
# 204                T060004_Result
# 205                       T060005
# 206                T060005_Result
# 207                       T060006
# 208                T060006_Result
# 209                       T060007
# 210                T060007_Result
# 211                       T060008
# 212                T060008_Result
# 213                       T060009
# 214                T060009_Result
# 215         T085001_Remeasurement
# 216  T085001_Remeasurement_Result
# 217         T085002_Remeasurement
# 218  T085002_Remeasurement_Result
# 219         T085003_Remeasurement
# 220  T085003_Remeasurement_Result
# 221         T085004_Remeasurement
# 222  T085004_Remeasurement_Result
# 223         T085005_Remeasurement
# 224  T085005_Remeasurement_Result
# 225         T085006_Remeasurement
# 226  T085006_Remeasurement_Result
# 227                   T086001_Arz
# 228            T086001_Arz_Result
# 229                   T086001_Kcl
# 230            T086001_Kcl_Result
# 231                   T086002_Arz
# 232            T086002_Arz_Result
# 233                   T086002_Kcl
# 234            T086002_Kcl_Result
# 235                   T086003_Arz
# 236            T086003_Arz_Result
# 237                   T086003_Kcl
# 238            T086003_Kcl_Result
# 239                   T086004_Arz
# 240            T086004_Arz_Result
# 241                   T086004_Kcl
# 242            T086004_Kcl_Result
# 243                   T086005_Arz
# 244            T086005_Arz_Result
# 245                   T086005_Kcl
# 246            T086005_Kcl_Result
# 247                   T086006_Arz
# 248            T086006_Arz_Result
# 249                   T086006_Kcl
# 250            T086006_Kcl_Result
# 251                   T086007_Arz
# 252            T086007_Arz_Result
# 253                   T086007_Kcl
# 254            T086007_Kcl_Result
# 255           T099001_Calibration
# 256    T099001_Calibration_Result
# 257                 T099001_Final
# 258          T099001_Final_Result
# 259           T099002_Calibration
# 260    T099002_Calibration_Result
# 261                 T099002_Final
# 262          T099002_Final_Result
# 263           T099003_Calibration
# 264    T099003_Calibration_Result
# 265                 T099003_Final
# 266          T099003_Final_Result
# 267           T099004_Calibration
# 268    T099004_Calibration_Result
# 269                 T099004_Final
# 270          T099004_Final_Result
# 271           T099005_Calibration
# 272    T099005_Calibration_Result
# 273                 T099005_Final
# 274          T099005_Final_Result
# 275           T099006_Calibration
# 276    T099006_Calibration_Result
# 277                 T099006_Final
# 278          T099006_Final_Result
# 279           T099007_Calibration
# 280    T099007_Calibration_Result
# 281                 T099007_Final
# 282          T099007_Final_Result
# 283           T099008_Calibration
# 284    T099008_Calibration_Result
# 285                 T099008_Final
# 286          T099008_Final_Result
# 287                           T15
# 288                    T15_Result
# 289                 T601001_Final
# 290          T601001_Final_Result
# 291                 T601001_Reset
# 292          T601001_Reset_Result
# 293                 X_OnSubstrate
# 294                 Y_OnSubstrate
# **************************************************
# C:\work\virtenvs\3p8_64bit_SensiPython_4p0\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
